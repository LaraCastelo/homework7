# %%
#Scrape the list of Arizona-based rock and mineral clubs

# %%
# https://rocktumbler.com/blog/rock-and-mineral-clubs/

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# !pip install lxml html5lib
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 5.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 5.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    ---------------------------------------- 2/2 [html5lib]
#
# ...
# WARNING: Cache entry deserialization failed, entry ignored

# %%
tables = pd.read_html("https://rocktumbler.com/blog/rock-and-mineral-clubs/")
tables
# Out:
# [                                0
#  0  Alabama Rock and Mineral Clubs,
#                                      0           1
#  0  Alabama Mineral & Lapidary Society  Birmingham
#  1           Dothan Gem & Mineral Club      Taylor
#  2  Huntsville Gem and Mineral Society  Huntsville
#  3           Mobile Rock & Gem Society      Mobile
#  4    Montgomery Gem & Mineral Society  Montgomery,
#                                 0
#  0  Alaska Rock and Mineral Clubs,
#                                 0          1
#  0  Chugach Gem & Mineral Society  Anchorage
#  1   Mat-Su Rock and Mineral Club     Palmer,
#                                  0
#  0  Arizona Rock and Mineral Clubs,
#                                              0                  1
#  0           Apache Junction Rock and Gem Club    Apache Junction
#  1                 Black Canyon City Rock Club  Black Canyon City
#  2          Daisy Mountain Rock & Mineral Club             Anthem
# ...

# %%
#ver quantas tabelas foram selecionadas > usando códigos do pandas

# %%
len(tables)
# Out:
# 113

# %%
# secionar só as do Arizona

# %%
tables[1]
# Out:
#                                     0           1
# 0  Alabama Mineral & Lapidary Society  Birmingham
# 1           Dothan Gem & Mineral Club      Taylor
# 2  Huntsville Gem and Mineral Society  Huntsville
# 3           Mobile Rock & Gem Society      Mobile
# 4    Montgomery Gem & Mineral Society  Montgomery

# %%
df=tables[5]
tables[5]
# Out:
#                                             0                  1
# 0           Apache Junction Rock and Gem Club    Apache Junction
# 1                 Black Canyon City Rock Club  Black Canyon City
# 2          Daisy Mountain Rock & Mineral Club             Anthem
# 3           Gila County Gem & Mineral Society              Miami
# 4               Huachuca Mineral and Gem Club       Sierra Vista
# 5           Lake Havasu Gem & Mineral Society   Lake Havasu City
# 6            Mineralogical Society of Arizona         Scottsdale
# 7                   Mingus Gem & Mineral Club         Cottonwood
# 8                    Mohave County Gemstoners            Kingman
# 9                    Old Pueblo Lapidary Club             Tucson
# 10              Pinal Gem and Mineral Society           Coolidge
# 11                Prescott Gem & Mineral Club  East Chino Valley
# 12  Quartzsite Roadrunners Gem & Mineral Club         Quartzsite
# ...

# %%
#salvar como csv

# %%
df.to_csv("arizona_rocks.csv", index=False)
